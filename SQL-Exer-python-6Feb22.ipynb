# %%
1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
2 . create a database called as cardataset
3 . create a table called as car with a column name given in dataset description
4 . Dump all the data into car table 
5 . try to check whttps://archive.ics.uci.edu/ml/datasets/Car+Evaluationeather all the data is aviable inside your table or not 
q6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value 
q7 . Try to filter a record where col 3 value will be 4 .
q8.  Try to update a col 3 value with 8 whereever you have value equal to 2 
q9 . try to delete table 
10 . Try to delete database

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='localhost',user='root',passwd='******')

# %%
cursor= mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testmanas',)]

# %%
cursor.execute("drop database cardataset")

# %%
cursor.execute("create database cardataset")

# %%
cursor.execute('CREATE TABLE cardataset.car (\
  buying varchar(10),\
  maint varchar(10) ,\
  doors varchar(10) ,\
  persons varchar(10) ,\
  lug_boot varchar(10) ,\
  safety varchar(10),\
    decision varchar(10)\
)'\
)

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testmanas',)]

# %%
cursor.execute("select * from cardataset.car")

# %%
cursor.fetchall()
# Out:
# []

# %%
import csv

# %%
with open('car_evaluation.csv','r') as f:
    car=csv.reader(f,delimiter='\n')
    for i in car:
        j=i[0].replace(",","','")
        j="'"+j+"'"
        cursor.execute(f"insert into cardataset.car values ({j}) ")
mydb.commit()

# %%
cursor.execute("select * from cardataset.car")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("select buying,count(*) from cardataset.car group by buying")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %%
cursor.execute("select doors,count(*) from cardataset.car group by doors")

# %%
cursor.fetchall()
# Out:
# [('2', 432), ('3', 432), ('4', 432), ('5more', 432)]

# %%
cursor.execute("select * from cardataset.car where doors=4")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("update cardataset.car set doors='8' where doors='2'")

# %%
cursor.execute("select * from cardataset.car where doors=2")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from cardataset.car where doors=8")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("drop table cardataset.car")

# %%
cursor.execute("select * from cardataset.car ")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /var/folders/d3/jyx0ypz13z3gzqt_7csw1nqc0000gn/T/ipykernel_6480/843540283.py in <module>
# ----> 1 cursor.execute("select * from cardataset.car ")
#
# /opt/anaconda3/lib/python3.9/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     570
#     571         try:
# --> 572             self._handle_result(self._connection.cmd_query(stmt))
#     573         except errors.InterfaceError:
#     574             if self._connection._have_next_result:  # pylint: disable=W0212
#
# /opt/anaconda3/lib/python3.9/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     918         query = bytes(packet)
#     919         try:
# --> 920             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
# ...

# %%
cursor.execute("drop database cardataset")

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('testmanas',)]
